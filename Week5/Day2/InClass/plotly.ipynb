# %%
import numpy as np

n = 100
x = np.linspace(0, 10, n)
y = np.sin(x) + np.random.normal(0, 0.1, n)

# %%
import plotly.express as px
import pandas as pd

# Sample data
df = pd.DataFrame({'x': x, 'y': y})

# Creating a line chart
fig = px.line(df, x='x', y='y')
fig.show()

# %%
# Creating an interactive scatter plot
fig = px.scatter(data, x='x', y='y', color='y')
fig.show()

# %%
fig.update_layout(title='Customized Plot', 
                  xaxis_title='X Axis', 
                  yaxis_title='Y Axis',
                  template='plotly_dark')
fig.show()

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Creating subplots
fig = make_subplots(rows=1, cols=2)
fig.add_trace(go.Scatter(x=data['x'], y=data['y']), row=1, col=1)
fig.add_trace(go.Bar(x=data['x'], y=data['y']), row=1, col=2)
fig.show()

# %%
# !pip install dash
# Out:
# Collecting dash
#   Downloading dash-2.18.0-py3-none-any.whl.metadata (10 kB)
# Collecting Flask<3.1,>=1.0.4 (from dash)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.4-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from dash) (5.24.0)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash)
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from dash) (74.1.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Collecting itsdangerous>=2.1.2 (from Flask<3.1,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: click>=8.1.3 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Collecting blinker>=1.6.2 (from Flask<3.1,>=1.0.4->dash)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: packaging in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from plotly>=5.0.0->dash) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from Werkzeug<3.1->dash) (2.1.5)
# Collecting zipp>=0.5 (from importlib-metadata->dash)
#   Downloading zipp-3.20.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from requests->dash) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from requests->dash) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from requests->dash) (2024.7.4)
# Requirement already satisfied: six>=1.7.0 in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in c:\users\vlad\developers_institute\practice\di_venv\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Downloading dash-2.18.0-py3-none-any.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.5 MB ? eta -:--:--
#    -------- ------------------------------- 1.6/7.5 MB 7.0 MB/s eta 0:00:01
#    --------------------- ------------------ 3.9/7.5 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 10.8 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading werkzeug-3.0.4-py3-none-any.whl (227 kB)
# Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading zipp-3.20.1-py3-none-any.whl (9.0 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, zipp, Werkzeug, retrying, itsdangerous, blinker, importlib-metadata, Flask, dash
# Successfully installed Flask-3.0.3 Werkzeug-3.0.4 blinker-1.8.2 dash-2.18.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 importlib-metadata-8.4.0 itsdangerous-2.2.0 retrying-1.3.4 zipp-3.20.1

# %%
import dash
from dash import dcc
from dash import html

app = dash.Dash()

app.layout = html.Div([
    dcc.Graph(figure=fig)
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df['z'] = np.random.rand(n)

# %%
# Example of a 3D scatter plot
fig = px.scatter_3d(df, x='x', y='y', z='z', color='y')
fig.show()
